# %% [markdown]
# CSV: To Read csv file method read_csv()
#     to_csv()

# %%
import pandas as pd
dataframe=pd.read_csv("/content/california_housing_train.csv")
dataframe
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
dataframe=pd.read_csv("/content/california_housing_train.csv",delimiter=",")
dataframe
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
dataframe=pd.read_csv("/content/california_housing_train.csv", na_values=["?","N/A","Negate"])
print(dataframe.head(8))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# ...

# %% [markdown]
# **CSV and TEXT**
#
# * Filepath: To select the file path from the directory, It could be string, pathlib, path, localpath, object, Buffer(StringIO)
# * SEP: Separator/Delimiter, Sniffer Tool, it to detect the delimiter automatically
# * delimiter:alternative to SEP
# * delim_whitespace: It is used specify where '' is used as delimiter
# * header: int, It is used to specify the row which is a header
# * names: List, It is used to specify which column names to be used as columns
# * index_col: It is used to select the column which will be used as a index
# * dtype: List, It is used to specify the data types of each column
# * data_parser: It is used to format the column which has the date as it's value
# * true_value: List
# * compression: gzip,zip,infer
# * encoding:'ut8'
# * iterator

# %%
import numpy as np
dataframe=pd.read_csv("/content/california_housing_train.csv",dtype={"ID": "float64","population":pd.Int64Dtype()})
print(dataframe)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
from io import StringIO
data="longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value\n1,2,3,4\n5,6,7,8"
data
dataframe=pd.read_csv(StringIO(data))
print(dataframe)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          1         2                   3            4             NaN
# 1          5         6                   7            8             NaN
#
#    population  households  median_income  median_house_value
# 0         NaN         NaN            NaN                 NaN
# 1         NaN         NaN            NaN                 NaN

# %%
data="longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value\n1,2,3,4\n5,6,7,8"
dataframe=pd.read_csv(StringIO(data))
dataframe["longitude"]=100
dataframe.to_csv("output.csv",index=False)

# %%
dataframe[["longitude","population"]].to_csv("Filtered_ouput.csv",index=False)

# %%
data="longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value\n1,2,3,4\n5,6,7,8"
dataframe=pd.read_csv(StringIO(data))
dataframe.to_csv("output.csv",mode='a',header=False)

# %% [markdown]
# **CHUNKS**

# %%
dataframe=pd.read_csv("/content/california_housing_train.csv",chunksize=7)
for chunk in dataframe:
  print(chunk.head())
# Out:
# Streaming output truncated to the last 5000 lines.
# 14310     -122.1     38.24                13.0       7367.0          1042.0
# 14311     -122.1     38.02                28.0       4308.0           824.0
# 14312     -122.1     37.97                18.0       4326.0           655.0
#
#        population  households  median_income  median_house_value
# 14308      1266.0       494.0         1.7566             58400.0
# 14309       512.0       197.0         2.4917             77100.0
# 14310      3193.0       983.0         5.3102            195000.0
# 14311      2086.0       776.0         3.6523            159700.0
# 14312      1753.0       646.0         5.6931            269600.0
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14315     -122.1     37.89                21.0       3282.0           653.0
# 14316     -122.1     37.88                35.0       3701.0           528.0
# ...

# %% [markdown]
# **CONCATENATION**

# %%
dataframe=pd.DataFrame({
    "longitude":[1,2,3,4],
    "latitude":[5,6,7,8],
    "housing_median_age":[12,23,44,33]

})
dataframe_2=pd.DataFrame({
    "longitude":[2,3,5,6],
    "latitude":[4,7,8,9],
    "housing_median_age":[11,22,33,44]
})
result=pd.concat([dataframe,dataframe_2])
print(result)
result=pd.concat([dataframe,dataframe_2],axis=1)
print(result)
# Out:
#    longitude  latitude  housing_median_age
# 0          1         5                  12
# 1          2         6                  23
# 2          3         7                  44
# 3          4         8                  33
# 0          2         4                  11
# 1          3         7                  22
# 2          5         8                  33
# 3          6         9                  44
#    longitude  latitude  housing_median_age  longitude  latitude  \
# 0          1         5                  12          2         4
# 1          2         6                  23          3         7
# 2          3         7                  44          5         8
# 3          4         8                  33          6         9
#
#    housing_median_age
# 0                  11
# 1                  22
# 2                  33
# 3                  44

# %% [markdown]
# **MERGE**

# %%
dataframe=pd.DataFrame({
    "longitude":[1,2,3,4],
    "latitude":[5,6,7,8],
    "housing_median_age":[12,23,44,33]

})
dataframe_2=pd.DataFrame({
    "longitude":[2,3,5,6],
    "latitude":[4,7,8,9],
    "housing_median_age":[11,22,33,44]
})
inner_join=pd.merge(dataframe,dataframe_2,on="longitude",how="inner")
print(inner_join)
left_join=pd.merge(dataframe,dataframe_2,on="longitude",how="left")
print(left_join)
outer_join=pd.merge(dataframe,dataframe_2,on="longitude",how="outer")
print(outer_join)
# Out:
#    longitude  latitude_x  housing_median_age_x  latitude_y  \
# 0          2           6                    23           4
# 1          3           7                    44           7
#
#    housing_median_age_y
# 0                    11
# 1                    22
#    longitude  latitude_x  housing_median_age_x  latitude_y  \
# 0          1           5                    12         NaN
# 1          2           6                    23         4.0
# 2          3           7                    44         7.0
# 3          4           8                    33         NaN
#
#    housing_median_age_y
# 0                   NaN
# 1                  11.0
# 2                  22.0
# 3                   NaN
#    longitude  latitude_x  housing_median_age_x  latitude_y  \
# 0          1         5.0                  12.0         NaN
# 1          2         6.0                  23.0         4.0
# 2          3         7.0                  44.0         7.0
# ...
